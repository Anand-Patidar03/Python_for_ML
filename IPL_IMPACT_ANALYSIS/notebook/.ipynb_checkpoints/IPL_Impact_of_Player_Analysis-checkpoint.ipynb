# %% [markdown]
# # IPL Impact of Player Analysis

# %% [markdown]
# ### 1) This project builds an Impact Score to evaluate IPL batters beyond traditional metrics like total runs.
# ### 2) This project also explain the performance of players based on various metrics

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### Why only Runs or average or strike rate is not enough to find the impact of a player in the team ?

# %% [markdown]
# - Runs, average, and strike rate individually provide incomplete insights. A player scoring many runs may lack consistency, while a high strike rate may come with instability—neither alone defines true match impact

# %% [markdown]
# #### Why impact matters ?

# %% [markdown]
# - That's why there is a term 'IMPACT' that is influence in the game.It never look for only single metric to define player's impact.
# Impact is considered on based of various metric such as runs score,strike rate,average,consistency like that..
#
# - In T20 cricket, impact matters more than raw numbers, as it reflects how effectively a player contributes to winning matches rather than just accumulating stats that is popularly known as 'Statpadding'.

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# - Traditional cricket metrics like runs, average, and strike rate provide limited insights into a player’s true performance. This project aims to identify the most impactful IPL batters by combining multiple factors such as scoring efficiency, consistency, and match contribution into a unified impact score. This approach enables a more holistic evaluation of player influence in T20 cricket.

# %% [markdown]
# ### Data Understanding

# %% [markdown]
# - The dataset consists of ball-by-ball IPL match data, providing detailed information about each delivery. Key columns such as batter, runs scored, dismissals, and match identifiers allow aggregation at player and match levels. This granular structure enables the computation of advanced metrics like strike rate, consistency, and contribution, which are crucial for assessing player impact.

# %% [markdown]
# - First of all let's take a glimpse towards our data that what we have
# - This IPL dataset i am using is taken from open source Kaggle plateform

# %%
# Let's import necessary libraries

from io import StringIO
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# dataset accessing
# I have named my whole dataset as ipl
ipl = pd.read_csv('../data/ipl.csv' , low_memory=False)

# %% [markdown]
# - now lets look as all the columns

# %%
ipl.head()  # so much columns but only few are for our means
# Out:
#    Unnamed: 0  match_id        date match_type             event_name  \
# 0      131970    335982  2008-04-18        T20  Indian Premier League
# 1      131971    335982  2008-04-18        T20  Indian Premier League
# 2      131972    335982  2008-04-18        T20  Indian Premier League
# 3      131973    335982  2008-04-18        T20  Indian Premier League
# 4      131974    335982  2008-04-18        T20  Indian Premier League
#
#    innings           batting_team                 bowling_team  over  ball  \
# 0        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 4        1  Kolkata Knight Riders  Royal Challengers Bangalore     0     4
#
#    ...  team_runs team_balls  team_wicket  new_batter  batter_runs  \
# 0  ...          1          1            0         NaN            0
# 1  ...          1          2            0         NaN            0
# 2  ...          2          2            0         NaN            0
# 3  ...          2          3            0         NaN            0
# 4  ...          2          4            0         NaN            0
#
#   batter_balls  bowler_wicket               batting_partners  next_batter  \
# 0            1              0  ('BB McCullum', 'SC Ganguly')          NaN
# 1            1              0  ('BB McCullum', 'SC Ganguly')          NaN
# 2            1              0  ('BB McCullum', 'SC Ganguly')          NaN
# 3            2              0  ('BB McCullum', 'SC Ganguly')          NaN
# 4            3              0  ('BB McCullum', 'SC Ganguly')          NaN
#
#    striker_out
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#
# [5 rows x 64 columns]

# %% [markdown]
# #### The columns require for our project are :-
# - batter → name of the batsman
# - runs_batter → runs scored by the batsmans
# - runs_total → total runs including extras
# - valid_ball → indicates legal deliveries
# - striker_out → whether batter got out
# - match_id → unique match identifier
# - batting_team → team batting

# %% [markdown]
# ## Feature Engineering
#
# - Now let's start understanding each metrics or features
#
# - Since the dataset is at ball-by-ball level, it is first aggregated at the batter level to compute total runs, balls faced, dismissals, and matches played.

# %%
bat = ipl.groupby('batter').agg(
    total_runs = ('runs_batter' , 'sum'),
    ball_faced = ('valid_ball' , 'sum'),
    matches_played = ('match_id' , 'nunique'),
    dismissals = ('striker_out' , lambda x : ((x == True)).sum())
).reset_index()

# Here i have named my new DataFrame as 'bat' 
# i have aggregate the ipl dataframe grouped by each batsman so that we can analyse features

# %% [markdown]
# - Now, To show what out 'bat' DataFrame contains we will do bat.head()

# %%
bat.head()     # Now as you can see it is not good to see performance of top performers so we will sort out in bat
# Out:
#            batter  total_runs  ball_faced  matches_played  dismissals
# 0  A Ashish Reddy         280         193              23          15
# 1        A Badoni         963         693              46          35
# 2      A Chandila           4           7               2           0
# 3        A Chopra          53          71               6           5
# 4     A Choudhary          25          20               3           1

# %%
bat.sort_values(by='total_runs'  ,ascending=False).head(20)

# Here you can see that i have taken out top 20 batsman based on total runs scored in IPL History
# Out:
#              batter  total_runs  ball_faced  matches_played  dismissals
# 658         V Kohli        8671        6505             259         217
# 500       RG Sharma        7048        5317             266         235
# 535        S Dhawan        6769        5304             221         187
# 151       DA Warner        6567        4680             184         158
# 569        SK Raina        5536        4025             200         162
# 389        MS Dhoni        5439        3935             241         139
# 297        KL Rahul        5235        3836             135         112
# 31   AB de Villiers        5181        3400             170         122
# 51        AM Rahane        5032        4021             183         160
# 128        CH Gayle        4997        3331             141         125
# 524      RV Uthappa        4954        3784             197         175
# 290      KD Karthik        4843        3570             233         175
# 193    F du Plessis        4773        3506             147         128
# 596       SV Samson        4704        3368             171         148
# 65        AT Rayudu        4348        3391             185         148
# 553        SA Yadav        4311        2889             151         120
# 199       G Gambhir        4217        3394             151         128
# 248      JC Buttler        4121        2749             119         101
# 376       MK Pandey        3951        3239             161         133
# 588       SR Watson        3880        2801             141         124

# %%
# bat = bat[((bat['ball_faced'] > 300) & (bat['matches_played'] > 30) & (bat['total_runs'] > 500))]

# %% [markdown]
# #### Strike Rate
#
# - Strike rate measures how quickly a batter scores runs and reflects scoring efficiency in T20 cricket.
# - What is Strike Rate :- It is (runs scored/total ball played) x 100

# %%
# in code form
# bat = bat[((bat['ball_faced'] > 300) & (bat['matches_played'] > 30) & (bat['total_runs'] > 500))] 
bat = bat[bat['total_runs'] > 200]  
bat['strike_rate'] = (bat['total_runs'] / bat['ball_faced'])*100

# as i will show you output that 'strike_rate' column will be added to our dataframe

# bat.sort_values(by='total_runs' , ascending=False).head(10)     # if sorted by total runs
bat.sort_values(by='strike_rate' , ascending=False).head(10)     # if sorted by strike rate
# Out:
#               batter  total_runs  ball_faced  matches_played  dismissals  \
# 663    V Suryavanshi         252         121               7           7
# 239  J Fraser-McGurk         385         191              15          14
# 10          A Mhatre         240         127               7           7
# 469    Priyansh Arya         545         298              18          18
# 426       Naman Dhir         392         216              19          14
# 449          PD Salt        1056         595              34          31
# 40        AD Russell        2655        1508             114          90
# 638         TH David         846         483              44          25
# 643          TM Head        1146         667              37          32
# 213        H Klaasen        1480         863              45          36
#
#      strike_rate
# 663   208.264463
# 239   201.570681
# 10    188.976378
# 469   182.885906
# 426   181.481481
# 449   177.478992
# 40    176.061008
# 638   175.155280
# 643   171.814093
# 213   171.494786

# %% [markdown]
# #### Average of Batsman
#
# - Batting average indicates consistency by measuring how many runs a player scores before getting dismissed.
# - What is Batting Average :- It is (runs scored/total dismissals of that batsman)

# %%
# in code form
# bat = bat[((bat['ball_faced'] > 300) & (bat['matches_played'] > 30) & (bat['total_runs'] > 500))] 
bat = bat[bat['total_runs'] > 200]  
bat['average'] = bat['total_runs'] / bat['dismissals']

# as i will show you output that 'average' column will be added to our dataframe

# bat.sort_values(by='total_runs' , ascending=False).head(10)     # if sorted by total runs
# bat.sort_values(by='strike_rate' , ascending=False).head(10)     # if sorted by strike rate
bat.sort_values(by='average' , ascending=False).head(10)     # if sorted by average
# Out:
#               batter  total_runs  ball_faced  matches_played  dismissals  \
# 98   B Sai Sudharsan        1793        1220              40          35
# 448   PD Collingwood         203         156               7           4
# 632         T Stubbs         711         431              30          15
# 297         KL Rahul        5235        3836             135         112
# 174        DP Conway        1080         770              28          24
# 219          HM Amla         577         406              16          13
# 610   Shashank Singh         773         490              33          18
# 31    AB de Villiers        5181        3400             170         122
# 268        JP Duminy        2029        1631              75          48
# 431          OA Shah         506         388              22          12
#
#      strike_rate    average
# 98    146.967213  51.228571
# 448   130.128205  50.750000
# 632   164.965197  47.400000
# 297   136.470282  46.741071
# 174   140.259740  45.000000
# 219   142.118227  44.384615
# 610   157.755102  42.944444
# 31    152.382353  42.467213
# 268   124.402207  42.270833
# 431   130.412371  42.166667

# %% [markdown]
# #### Runs Per Match
#
# - Runs per match captures a player’s overall contribution across matches, balancing performance over time.
# - many people thought that it is same as average but it is not because it also add that matched where he was notout
# - What is Runs Per Match :- It is (runs scored/total matches played by that batsman)

# %%
# in code form

bat['runs_per_match'] = bat['total_runs'] / bat['matches_played']

# as in the output 'runs_per_match' column will be added to our dataframe

bat.sort_values(by='total_runs' , ascending=False).head(10)     # if sorted by total runs
# bat.sort_values(by='strike_rate' , ascending=False).head(10)     # if sorted by strike rate
# bat.sort_values(by='average' , ascending=False).head(10)     # if sorted by average
# bat.sort_values(by='runs_per_match' , ascending=False).head(10)     # if sorted by runs_per_match
# Out:
#              batter  total_runs  ball_faced  matches_played  dismissals  \
# 658         V Kohli        8671        6505             259         217
# 500       RG Sharma        7048        5317             266         235
# 535        S Dhawan        6769        5304             221         187
# 151       DA Warner        6567        4680             184         158
# 569        SK Raina        5536        4025             200         162
# 389        MS Dhoni        5439        3935             241         139
# 297        KL Rahul        5235        3836             135         112
# 31   AB de Villiers        5181        3400             170         122
# 51        AM Rahane        5032        4021             183         160
# 128        CH Gayle        4997        3331             141         125
#
#      strike_rate    average  runs_per_match
# 658   133.297463  39.958525       33.478764
# 500   132.555953  29.991489       26.496241
# 535   127.620664  36.197861       30.628959
# 151   140.320513  41.563291       35.690217
# 569   137.540373  34.172840       27.680000
# 389   138.221093  39.129496       22.568465
# 297   136.470282  46.741071       38.777778
# 31    152.382353  42.467213       30.476471
# 51    125.142999  31.450000       27.497268
# 128   150.015011  39.976000       35.439716

# %% [markdown]
# #### Contribution %
#
# - now for contribution % we will derive the stats in detail but for now we will understand what contribution means
# - What is Contribution % :- It is (batter_runs / team_runs) * 100

# %% [markdown]
# #### Consistency (CV)
#
# - now for Consistency (CV) also we will derive the stats in detail but for now we will understand what Consistency (CV) means
# - What is Consistency (CV) :- It is cv (standard_deviation of runs / mean of runs)

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# - now let us show dataframe and plotting also to visualize what we have got using feature engineering

# %% [markdown]
# ### plot top run getters using bar plotting

# %%
# this was our code for top 10 run getters
top_10 = bat.sort_values(by='total_runs' , ascending=False).head(10)

# Now for plotting Bar Graph we will use MatPlotLib

plt.figure(figsize=(14,7))                                 # It will define the figure size of out graph
plt.bar(top_10['batter'] ,top_10['total_runs'] )                 # It will plot graph between batsman v/s Total Runs
plt.title("Top 10 run getters in IPL History" , fontsize=18 , fontweight='bold')            # It will add Title for our Bar Plot
plt.xlabel("Batsman" , fontsize=14)                        # It will lable our X-axis to 'Batsman'
plt.ylabel("Total Runs",fontsize=14)                       # It will lable our Y-axis to 'Total Runs'
plt.xticks(rotation = 45,fontsize = 12)                    # It will change fontsize of x-axis entries for better visuals and rotate names by 45 degree
plt.yticks(fontsize = 12)                                  # It will change fontsize of y-axis entries for better visuals


for i in range(len(top_10)):
    plt.text(i,
             top_10['total_runs'].iloc[i]+50,               # this peace of code will show the exact runs of batsman above each bar 
             top_10['total_runs'].iloc[i],
             ha='center', fontsize=11)

    
plt.show()

# %% [markdown]
# ### plot for top 10 batsman with most Strike rate using bar plotting

# %%
# this was our code for top 10 batsman with most strike rate

top_10 = bat[bat['total_runs'] > 200]     # I have filtered out the noises means that batsman must have scored above some threshold runs (here 200)

top_10 = top_10.sort_values(by='strike_rate' , ascending=False).head(10)

# Similarly for plotting Bar Graph we will use MatPlotLib

plt.figure(figsize=(14,7))                                 # It will define the figure size of out graph
plt.bar(top_10['batter'] ,top_10['strike_rate'] )                 # It will plot graph between batsman v/s Strike rate
plt.title("Top 10 batsman with most Strike Rate (min 200 runs)" , fontsize=18 , fontweight='bold')            # It will add Title for our Bar Plot
plt.xlabel("Batsman" , fontsize=14)                        # It will lable our X-axis to 'Batsman'
plt.ylabel("Strike Rate",fontsize=14)                       # It will lable our Y-axis to 'Strike rate'
plt.xticks(rotation = 45,fontsize = 12)                    # It will change fontsize of x-axis entries for better visuals and rotate names by 45 degree
plt.yticks(fontsize = 12)                                  # It will change fontsize of y-axis entries for better visuals
plt.axhline(y=150, linestyle='--' , c="b")

for i in range(len(top_10)):
    plt.text(top_10['batter'].iloc[i],
             top_10['strike_rate'].iloc[i]+3,               # this peace of code will show the exact strike rate of batsman above each bar 
             round(top_10['strike_rate'].iloc[i], 2),
             ha='center', fontsize=10)

    
plt.show()

# %% [markdown]
# ### plot for top 10 batsman with best average using bar plotting

# %%
# this was our code for top 10 batsman with best average

top_10 = bat[bat['total_runs'] > 200]     # I have filtered out the noises means that batsman must have scored above some threshold runs (here 200)

top_10 = top_10.sort_values(by='average' , ascending=False).head(10)

# Similarly for plotting Bar Graph we will use MatPlotLib

plt.figure(figsize=(14,7))                                 # It will define the figure size of out graph
plt.bar(top_10['batter'] ,top_10['average'] )                 # It will plot graph between batsman v/s Average
plt.title("Top 10 batsman with best average (min 200 runs)" , fontsize=18 , fontweight='bold')            # It will add Title for our Bar Plot
plt.xlabel("Batsman" , fontsize=14)                        # It will lable our X-axis to 'Batsman'
plt.ylabel("Average",fontsize=14)                       # It will lable our Y-axis to 'Average'
plt.xticks(rotation = 45,fontsize = 12)                    # It will change fontsize of x-axis entries for better visuals and rotate names by 45 degree
plt.yticks(fontsize = 12)                                  # It will change fontsize of y-axis entries for better visuals
plt.axhline(y=40, linestyle='--' , c="y")

for i in range(len(top_10)):
    plt.text(top_10['batter'].iloc[i],
             top_10['average'].iloc[i]+0.5,               # this peace of code will show the exact Average of batsman above each bar 
             round(top_10['average'].iloc[i], 2),
             ha='center', fontsize=10)

    
plt.show()

# %% [markdown]
# ## Insights from this analysis
#
# - High run scorers are not always high strike rate players
# - Some players maintain both consistency and aggression

# %% [markdown]
# ## Now we will look at Impact of Player
#
# - we will first normalize our data for fair analysis

# %%
# We will bring all our data between 0 to 1 for fair comparison

bat['sr_norm'] = bat['strike_rate'] / bat['strike_rate'].max()
bat['avg_norm'] = bat['average'] / bat['average'].max()
bat['rpm_norm'] = bat['runs_per_match'] / bat['runs_per_match'].max()

# %% [markdown]
# - Now think about how to define Impact of a player .
# - Yes ! Using all feature component
# - now main question is how we measure impact using all these metrics here is a good formula
# - impact = (0.4 * sr_norm) + (0.3 * avg_norm) + (0.3 * rpm_norm)

# %%
# in code form

# adding threshold for removing noise 


bat['impact'] = (0.4 * bat['sr_norm']) + (0.3 * bat['avg_norm']) + (0.3 * bat['rpm_norm'])

# as i will show you output that 'impact' column will be added to our dataframe

bat.sort_values(by='impact' , ascending=False).head(10)     # if sorted by total runs
# Out:
#               batter  total_runs  ball_faced  matches_played  dismissals  \
# 98   B Sai Sudharsan        1793        1220              40          35
# 663    V Suryavanshi         252         121               7           7
# 297         KL Rahul        5235        3836             135         112
# 10          A Mhatre         240         127               7           7
# 174        DP Conway        1080         770              28          24
# 213        H Klaasen        1480         863              45          36
# 219          HM Amla         577         406              16          13
# 128         CH Gayle        4997        3331             141         125
# 248       JC Buttler        4121        2749             119         101
# 632         T Stubbs         711         431              30          15
#
#      strike_rate    average  runs_per_match   sr_norm  avg_norm  rpm_norm  \
# 98    146.967213  51.228571       44.825000  0.705676  1.000000  1.000000
# 663   208.264463  36.000000       36.000000  1.000000  0.702733  0.803123
# 297   136.470282  46.741071       38.777778  0.655274  0.912402  0.865093
# 10    188.976378  34.285714       34.285714  0.907387  0.669269  0.764879
# 174   140.259740  45.000000       38.571429  0.673469  0.878416  0.860489
# 213   171.494786  41.111111       32.888889  0.823447  0.802504  0.733718
# 219   142.118227  44.384615       36.062500  0.682393  0.866404  0.804518
# 128   150.015011  39.976000       35.439716  0.720310  0.780346  0.790624
# 248   149.909058  40.801980       34.630252  0.719801  0.796469  0.772566
# 632   164.965197  47.400000       23.700000  0.792095  0.925265  0.528723
#
#        impact
# 98   0.882270
# 663  0.851757
# 297  0.795358
# 10   0.793199
# 174  0.791059
# 213  0.790245
# 219  0.774234
# 128  0.759415
# 248  0.758631
# 632  0.753034

# %% [markdown]
# ### plot for top 10 batsman with highest impact using bar plotting

# %%
# this was our code for top 10 batsman with best average


top_10 = bat.sort_values(by='impact' , ascending=False).head(10)

# Similarly for plotting Bar Graph we will use MatPlotLib

plt.figure(figsize=(14,7))                                 # It will define the figure size of out graph
plt.bar(top_10['batter'] ,top_10['impact'] )                 # It will plot graph between batsman v/s Average
plt.title("Top 10 batsman with highest impact" , fontsize=18 , fontweight='bold')            # It will add Title for our Bar Plot
plt.xlabel("Batsman" , fontsize=14)                        # It will lable our X-axis to 'Batsman'
plt.ylabel("Impact Score",fontsize=14)                       # It will lable our Y-axis to 'Average'
plt.xticks(rotation = 45,fontsize = 12)                    # It will change fontsize of x-axis entries for better visuals and rotate names by 45 degree
plt.yticks(fontsize = 12)                                  # It will change fontsize of y-axis entries for better visuals
plt.axhline(y=0.60, linestyle='--' , c="r")

for i in range(len(top_10)):
    plt.text(top_10['batter'].iloc[i],
             top_10['impact'].iloc[i] +0.01,               # this peace of code will show the exact Average of batsman above each bar 
             round(top_10['impact'].iloc[i], 3),
             ha='center', fontsize=10)

    
plt.show()

# %% [markdown]
# ## Now how to look at consistency of a player
#
# - Consistency is measured using the Coefficient of Variation (CV), which captures variability in a batter’s performance relative to their average. Lower CV indicates more consistent performance.

# %%
# in code form 

# we calculate the runs of a batsman in each match
batter_match_runs = ipl.groupby(['batter', 'match_id'])['runs_batter'].sum().reset_index()

# then we will find the mean and varience of runs scored by  that batsman
consistency = batter_match_runs.groupby('batter')['runs_batter'].agg(['mean','var']).reset_index()

# now calculate consistency using formula (standard deviation / mean)
bat['consistency'] = consistency['var'] / consistency['var'].max()
consistency['std'] = consistency['var'] ** 0.5
bat['cv'] = consistency['std'] / consistency['mean']    # in bat dataframe 'cv' column will be added and whoose c is less then he is more consistence

bat.sort_values(by='cv' , ascending=True).head(10)
# Out:
#               batter  total_runs  ball_faced  matches_played  dismissals  \
# 98   B Sai Sudharsan        1793        1220              40          35
# 16     A Raghuvanshi         463         319              18          16
# 649      Tilak Varma        1499        1032              51          38
# 142         D Brevis         455         297              16          16
# 164      DJ Mitchell         351         267              15          13
# 566    SE Rutherford         397         288              20          16
# 0     A Ashish Reddy         280         193              23          15
# 475         R Dravid        2174        1878              82          75
# 48        AK Markram        1440        1062              55          46
# 496     RD Rickelton         388         255              14          13
#
#      strike_rate    average  runs_per_match   sr_norm  avg_norm  rpm_norm  \
# 98    146.967213  51.228571       44.825000  0.705676  1.000000  1.000000
# 16    145.141066  28.937500       25.722222  0.696907  0.564870  0.573837
# 649   145.251938  39.447368       29.392157  0.697440  0.770027  0.655709
# 142   153.198653  28.437500       28.437500  0.735597  0.555110  0.634412
# 164   131.460674  27.000000       23.400000  0.631220  0.527050  0.522030
# 566   137.847222  24.812500       19.850000  0.661885  0.484349  0.442833
# 0     145.077720  18.666667       12.173913  0.696603  0.364380  0.271588
# 475   115.761448  28.986667       26.512195  0.555839  0.565830  0.591460
# 48    135.593220  31.304348       26.181818  0.651063  0.611072  0.584090
# 496   152.156863  29.846154       27.714286  0.730594  0.582608  0.618277
#
#        impact  consistency        cv
# 98   0.882270     0.519289  0.602647
# 16   0.620375     0.187765  0.631507
# 649  0.706697     0.268507  0.660884
# 142  0.651095     0.278569  0.695751
# 164  0.567212     0.194453  0.706431
# 566  0.542909     0.145863  0.721259
# 0    0.469432     0.056065  0.729115
# 475  0.569523     0.271137  0.736253
# 48   0.618974     0.264827  0.736818
# 496  0.652503     0.299252  0.739935

# %% [markdown]
# ### plot for top 10 batsman with good consistency using bar plotting

# %%
# this was our code for top 10 batsman with best average


top_10 = bat.sort_values(by='cv' , ascending=True).head(10)

# Similarly for plotting Bar Graph we will use MatPlotLib

plt.figure(figsize=(14,7))                                 # It will define the figure size of out graph
plt.bar(top_10['batter'] ,top_10['cv'] )                 # It will plot graph between batsman v/s Average
plt.title("Top 10 batsman with highest consistency" , fontsize=18 , fontweight='bold')            # It will add Title for our Bar Plot
plt.xlabel("Batsman" , fontsize=14)                        # It will lable our X-axis to 'Batsman'
plt.ylabel("Consistency Score",fontsize=14)                       # It will lable our Y-axis to 'Average'
plt.xticks(rotation = 45,fontsize = 10)                    # It will change fontsize of x-axis entries for better visuals and rotate names by 45 degree
plt.yticks(fontsize = 12)                                  # It will change fontsize of y-axis entries for better visuals
plt.axhline(y=0.70, linestyle='--' , c="c")

for i in range(len(top_10)):
    plt.text(top_10['batter'].iloc[i],
             top_10['cv'].iloc[i] +0.01,               # this peace of code will show the exact Average of batsman above each bar 
             round(top_10['cv'].iloc[i], 3),
             ha='center', fontsize=10)

    
plt.show()

# %% [markdown]
# ## Now we will distribute the category of batsman into different clusters using scatter plot
#
# ## Strike Rate v/s Average    comparison

# %% [markdown]
# - To better interpret player performance, batters are grouped into distinct categories using thresholds on strike rate and average. This role-based segmentation helps differentiate between aggressive players, anchors, and elite performers. The scatter plot visualizes these categories, while top impact players are annotated to highlight key contributors.

# %%
# Categorise the Batsmans into different categories

def category(row):
    if row['strike_rate'] >= 150 and row['average'] >= 35:
        return 'Elite'
    elif row['strike_rate'] >= 150 and row['average'] < 35:
        return 'Aggressive'
    elif row['strike_rate'] < 150 and row['average'] >= 35:
        return 'Anchor'
    elif 130 <= row['strike_rate'] < 150 and 25 <= row['average'] < 35:
        return 'Average'
    else:
        return 'Weak'

bat['category'] = bat.apply(category, axis=1)


plt.figure(figsize=(12,7))

for cat, data in bat.groupby('category'):
    plt.scatter(data['average'], data['strike_rate'], label=cat)

top = bat.sort_values(by='impact', ascending=False).head(30)

for i in range(len(top)):
    plt.text(
        top['average'].iloc[i],
        top['strike_rate'].iloc[i],
        top['batter'].iloc[i],
        fontsize=7
    )

plt.axvline(x=35, linestyle='--',c='k')
plt.axhline(y=150, linestyle='--',c='k')
plt.axhline(y=130, linestyle='--',c='k') 
plt.axvline(x=25, linestyle='--',c='k')

plt.legend()
plt.title("Batsman category distribution based in Strike Rate v/s Average" , fontsize=18 , fontweight='bold')            # It will add Title for our Bar Plot
plt.xlabel("Average" , fontsize=14)                        # It will lable our X-axis to 'Batsman'
plt.ylabel("Strike rate",fontsize=14)                       # It will lable our Y-axis to 'Average'


plt.show()

# %% [markdown]
# ### Insights from this scatter plot

# %% [markdown]
# - Players with high strike rate but low average are inconsistent
# - Anchors contribute more but have lower impact

# %% [markdown]
# - This section segments batters into distinct roles based on their strike rate and average to better understand their playing style and impact. By defining threshold-based categories such as Elite, Aggressive, Anchor, and others, the analysis moves beyond traditional metrics to capture different dimensions of performance. The scatter plot visualizes these roles, while top impact players are annotated to highlight key performers and provide deeper insight into how different types of batters contribute to the game.

# %% [markdown]
# ## Final Conclusion

# %% [markdown]
# 1. High Runs is not always High Impact
#
# - It was observed that players with the highest total runs are not always the most impactful.
# - Player like Shikhar Dhawan , Ajinkya Rahane accumulate runs at a slower strike rate.
# - On other hande player like JFM , Priyansh Arya score fewer runs but contribute more aggressively.
# - This shows that strike rate plays a crucial role in impact.
#
# 2. Strike Rate is a Game-Changer
#
# - Players with higher strike rates like Vaibhav Sooryavanshi, Henrich Klassan tend to rank higher in the Impact Score.
# - Aggressive players can change the momentum of the match quickly.
# - Even with fewer balls faced, they create significant impact.
# - This highlights the importance of scoring efficiency over volume.
#
# 3. Consistency (Average) Matters
#
# - Players with a good average like Sai Sudarshan tend to have stable performance across matches.
# - High average indicates reliability.
# - These players may not always be explosive but are dependable.
# - A balance of consistency + aggression = high impact
#
# 4. Underrated Players Identified
#
# - Player like Sai Sudarshan and vaibhav Sooryavanshi who are not among the top run scorers still rank high in Impact Score.
# - These players often have:
# - High strike rates
# - Good match contribution
# - They are often overlooked in traditional analysis.
# - This analysis helps in identifying hidden gems.
#
# 5. Balanced Players Dominate Rankings
#
# - Top impactful players usually have:
# - Good total runs
# - High strike rate
# - Decent average
# - Players strong in all aspects outperform specialists.
#
# 6. Impact Score Provides Holistic Evaluation
#
# - The custom Impact Score successfully combines:
# - Performance (runs)
# - Efficiency (strike rate)
# - Consistency (average)
# - This gives a more complete picture than any single metric.
