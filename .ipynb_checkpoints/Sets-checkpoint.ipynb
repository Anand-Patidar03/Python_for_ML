# %% [markdown]
# # Sets in python

# %% [markdown]
# -What is a Set
# Concept
#
# A Set is an unordered collection of unique elements.
#
# Key properties:
#
# No duplicate values
#
# Unordered (no indexing)
#
# Mutable
#
# Fast membership checking

# %%
st = set()
type(st)
# Out:
# set

# %%
st = {1,2,3,4,5}
print(st)
# Out:
# {1, 2, 3, 4, 5}

# %%
print(type(st))
# Out:
# <class 'set'>

# %%
sport = {"Cricket","Football","Hockey","Golf"}
print(sport)
print(len(sport))
# Out:
# {'Cricket', 'Football', 'Golf', 'Hockey'}
# 4

# %%
nums = {1,2,3,4,2,3,5,4,3,2}
print(nums)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = set([1,2,3,4])
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s = set([1,2,3,"anand",6,7,"patidar","hello",8,2,6,7,8,9,90,8,6,5,54,4])
print(s)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 'anand', 'patidar', 'hello', 54, 90}

# %%
sport.add("vollyball")
print(sport)
# Out:
# {'Cricket', 'Football', 'Hockey', 'vollyball', 'Golf'}

# %%
set1 = {1,2,3,4,5}
set2 = {2,7,8,9,6}
print(set1)
print(set2)
# Out:
# {1, 2, 3, 4, 5}
# {2, 6, 7, 8, 9}

# %%
set1.intersection(set2)
# Out:
# {2}

# %%
set2.intersection(set1)
# Out:
# {2}

# %%
set2.difference(set1)
# Out:
# {6, 7, 8, 9}

# %%
set1.difference(set2)
print(set1)
# Out:
# {1, 3, 4, 5}

# %%
set1.difference_update(set2)

# %%
print(set1)
print(set2)
# Out:
# {1, 3, 4, 5}
# {2, 6, 7, 8, 9}

# %%
set1.add(2)
print(set1)
print(set2)
# Out:
# {1, 2, 3, 4, 5}
# {2, 6, 7, 8, 9}

# %%
set2.difference_update(set1)   # make change in set2
print(set1)
print(set2)
# Out:
# {1, 2, 3, 4, 5}
# {6, 7, 8, 9}

# %%
st = set()
type(st)
# Out:
# set

# %%
st = {}
type(st)
# Out:
# dict

# %%
st = set()
st.add(1)

# %%
st.add(2)  #add single value
st.add(3)
print(st)
# Out:
# {1, 2, 3, 7}

# %%
st.update([5,6,7])  # add multiple values
print(st)
# Out:
# {1, 2, 3, 5, 7, 6}

# %%
st.remove(5)  #if element is not present then error
print(st)
# Out:
# {1, 2, 3, 7, 6}

# %%
st.discard(0)  #f element not present simply ignore
print(st)
# Out:
# {1, 2, 3, 7, 6}

# %%
st.discard(3)
print(st)
# Out:
# {1, 2, 7}

# %%
print(st.pop())
# Out:
# 1

# %%
st = {1,2,3,4,5,6,7}
print(st.pop())
# Out:
# 1

# %%
print(3 in st)
# Out:
# True

# %%
print(1 in st)
# Out:
# False

# %%
print(6 in s)
# Out:
# True

# %%
st1 = {1,2,3,4}
st2 = {3,4,5,6}
print(st1-st2)
# Out:
# {1, 2}

# %%
print(st1^st2)
# Out:
# {1, 2, 5, 6}

# %%
lst = list(st1)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
print(st)
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
for i in st:
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
stt = {i*i for i in range(6)}
print(stt)
# Out:
# {0, 1, 4, 9, 16, 25}
