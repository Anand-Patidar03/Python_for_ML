# %%
# this is my first program in jupyter

# %%
1+1
# Out:
# 2

# %% [raw]
# this is raw data

# %%
3*8
# Out:
# 24

# %% [markdown]
# # this is python tutorial
# # let's start
# - Datatypes

# %%
type("anand")
# Out:
# str

# %%
3 * "Anand"
# Out:
# 'AnandAnandAnand'

# %%
a=10
type(a)
# Out:
# int

# %%
a = 20
type(a)
# Out:
# int

# %%
a = "Anand Patiar"

# %%
type(a)
# Out:
# str

# %%
a = 9.0

# %%
type(a)
# Out:
# float

# %%
first_name = "Anand"
Last_name = "Patidar"

# %%
print("my name is {} and surname is {}".format(first_name,Last_name))
# Out:
# my name is Anand and surname is Patidar

# %%
print("my name is {first} and surname is {last}".format(first = first_name,last = Last_name))
# Out:
# my name is Anand and surname is Patidar

# %%
2 + 4
# Out:
# 6

# %% [markdown]
# ## now lets's move to next step towards python basics
