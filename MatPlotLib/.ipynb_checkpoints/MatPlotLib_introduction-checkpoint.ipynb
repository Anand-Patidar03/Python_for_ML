# %% [markdown]
# # MatPlotLib

# %% [markdown]
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# - Generally easy to get started for simple plots
# - Support for custom labels and texts
# - Great control of every element in a figure
# - High-quality output in many formats
# - Very customizable in general

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
x = np.arange(0,10)
y = np.arange(11,21)

# %%
# Scatter Plot

plt.scatter(x,y,c='r')
plt.xlabel("X-axis")
plt.ylabel('Y-axis')
plt.title('Graph in 2D')
plt.show()   # if that line (%matplotlib inline) is not written

# %%
# plt Plot
y = x*x
plt.plot(x,y,'g*',linestyle="dashed",linewidth=2,markersize=10)
plt.xlabel("X-axis")
plt.ylabel('Y-axis')
plt.title("2D graph with Plot")
# Out:
# Text(0.5, 1.0, '2D graph with Plot')

# %%
# creating subplot

plt.subplot(2,3,1)
plt.plot(x,y,'r')
plt.subplot(2,3,2)
plt.plot(x,y,'g')
plt.subplot(2,3,3)
plt.plot(x,y,'b')
plt.subplot(2,3,4)
plt.plot(x,y,'c')

# %%
# Sine waves

plt.figure(figsize=(6, 2.5))  # defines size of figure
x = np.arange(0,4*np.pi , 0.1)
y = np.sin(x)

plt.plot(x,y,'g--')

# %%
# Sine and Cosine waves

x = np.arange(0, 5*np.pi , 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.figure(figsize=(5, 3))

plt.subplot(2,2,1)
plt.plot(x,y_sin,'r--')
plt.title("Sine Wave")
plt.xlabel("X-sinaxis")
plt.ylabel('Y-sinaxis')

plt.subplot(2,2,4)
plt.plot(x,y_cos,'b--')
plt.title('Cosine Wave')
plt.xlabel("X-cosineaxis")
plt.ylabel('Y-cosineaxis')
# Out:
# Text(0, 0.5, 'Y-cosineaxis')

# %%
# Bar plot

plt.figure(figsize=(5, 3))
x1 = [2,5,12]
y1 = [11,16,9]

x2 = [3,9,15]
y2 = [6,15,7]

plt.bar(x1,y1,color = 'g')
plt.bar(x2,y2,color='r')
plt.title('Bar Plot')
plt.xlabel("X-axis")
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
# Histogram

plt.figure(figsize=(5, 3))
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a, bins=10)      # by default bins are 10
plt.title('Histogram')
plt.xlabel("X-axis")
# Out:
# Text(0.5, 0, 'X-axis')

# %%
#  Box Plot

plt.figure(figsize=(5, 3))
data = [np.random.normal(0,std , 100) for std in range(1,4)]

plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20ca01f6850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20ca01f6ad0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x20ca01f6710>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x20ca01f6d50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x20ca01f6e90>,
# ...
#  'means': []}

# %%
# Pie Chart

plt.figure(figsize=(5, 3))
lang = ['Python', 'C++' , 'Java' , 'Ruby' , 'Javascript']
sizes = [150 , 210 , 120 , 30 , 90]
colors = ['blue' , 'red' ,'green' ,'orange' , 'yellow']
explode = (0.1,0,0.15,0,0)

plt.pie(sizes , explode=explode , labels=lang , colors=colors, autopct = '%1.0f%%' , shadow = True)
plt.axis(True)
# Out:
# (np.float64(-1.25), np.float64(1.25), np.float64(-1.25), np.float64(1.25))
